# %%
import numpy as np
import matplotlib.pyplot as plt

# 경고메세지 없애기
import warnings
warnings.filterwarnings('ignore')

# %%
data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([ -42,   47,  -15,  -52,  -77,  -23,   15,   44,   78,  119,  124,
#         131,  133,   52,  -42,   50,  -28,  -78,  -34, -110,  -52, -122,
#        -105, -190, -165, -233, -198, -256, -344, -398, -329, -274, -326,
#        -231, -246, -329, -310, -405, -327, -307, -380, -356, -259, -322,
#        -411, -374, -278, -266, -227, -210])

# %%
plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#1. 폰트파일로 FontProperties()
import matplotlib.font_manager as fm

path = 'HANDOTUM.TTF'
fontprop = fm.FontProperties(fname = path, size=14)

data = np.random.randint(-100,100,50).cumsum()
plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이', fontproperties = fontprop)
plt.ylabel('주식 가격', fontproperties = fontprop)
plt.xlabel('시간(분)', fontproperties = fontprop)
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#2 rcParams[]을 설정
import matplotlib

print('설정 파일 위치:', matplotlib.matplotlib_fname())
print('기본 설정 폰트:', plt.rcParams['font.family'])
print('기본 설정 크기:', plt.rcParams['font.size'])
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12

# 마이너스 값이 안깨지게 하는방법
plt.rcParams['axes.unicode_minus'] = False

print('기본 설정 폰트:', plt.rcParams['font.family'])
print('기본 설정 크기:', plt.rcParams['font.size'])
# Out:
# 설정 파일 위치: C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트: ['NanumSquare']
# 기본 설정 크기: 10.0
# 기본 설정 폰트: ['Malgun Gothic']
# 기본 설정 크기: 12.0

# %%
data = np.random.randint(-100,100,50).cumsum()
plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#3. 설정파일에 셋팅

print('설정 파일 위치:', matplotlib.matplotlib_fname())
[font.name for font in fm.fontManager.ttflist if 'Nanum' in font.name]
# Out:
# 설정 파일 위치: C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\mpl-data\matplotlibrc
# ['NanumSquare_ac',
#  'NanumSquare_ac',
#  'NanumSquare_ac',
#  'NanumSquare_ac',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquare']
